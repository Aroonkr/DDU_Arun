# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('netflix_titles_2021.csv')

# %%
df.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
df.date_added.unique()
# Out:
# array(['September 25, 2021', 'September 24, 2021', 'September 23, 2021',
#        ..., 'December 6, 2018', 'March 9, 2016', 'January 11, 2020'],
#       dtype=object)

# %%
df.tail(6)

# %%
df.sample()

# %%
df.shape

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[50:51] #multiple coloumns show cheyyan
# Out:
#    show_id     type                                              title  \
# 50     s51  TV Show                                      Dharmakshetra
# 51     s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
#
#              director                                               cast  \
# 50                NaN  Kashmira Irani, Chandan Anand, Dinesh Mehta, A...
# 51  Toshiya Shinohara  Kappei Yamaguchi, Satsuki Yukino, Mieko Harada...
#
#    country          date_added  release_year rating  duration  \
# 50   India  September 15, 2021          2014  TV-PG  1 Season
# 51   Japan  September 15, 2021          2002  TV-14    99 min
#
#                                             listed_in  \
# 50  International TV Shows, TV Dramas, TV Sci-Fi &...
# 51  Action & Adventure, Anime Features, Internatio...
#
#                                           description
# 50  After the ancient Great War, the god Chitragup...
# 51  With their biggest foe seemingly defeated, Inu...

# %%
df.director.value_counts() #value_counts() function returns object containing counts of unique values
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
x=df.groupby(by="director").title    #used to split the data into groups based on condition
x.first()
# Out:
# director
# A. L. Vijay                           Watchman
# A. Raajdheep                        Asura Guru
# A. Salaam                            Salaakhen
# A.R. Murugadoss                         Sarkar
# Aadish Keluskar        Jaoon Kahan Bata Ae Dil
#                                 ...
# Çagan Irmak                     Babam ve Oğlum
# Ísold Uggadóttir          And Breathe Normally
# Óskar Thór Axelsson                 Ég man þig
# Ömer Faruk Sorak                       G.O.R.A
# Şenol Sönmez                     Hayat Öpücügü
# Name: title, Length: 4528, dtype: object

# %%
df.sort_values(by='show_id', ascending=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'United States'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.query('release_year==2021 & country=="United States"')
# Out:
#      show_id     type                                   title  \
# 9        s10    Movie                            The Starling
# 15       s16  TV Show                       Dear White People
# 40       s41  TV Show  He-Man and the Masters of the Universe
# 55       s56  TV Show                               Nailed It
# 81       s82    Movie                                    Kate
# ...      ...      ...                                     ...
# 1449   s1450  TV Show                     Dream Home Makeover
# 1455   s1456  TV Show           Headspace Guide to Meditation
# 1466   s1467    Movie            The Minimalists: Less Is Now
# 2920   s2921  TV Show                           Love Is Blind
# 8437   s8438  TV Show                  The Netflix Afterparty
#
#                    director  \
# 9            Theodore Melfi
# 15                      NaN
# 40                      NaN
# 55                      NaN
# 81    Cedric Nicolas-Troyan
# ...                     ...
# ...

# %%
"24","25","24","25","25","25","24","24","24","24","25","23","24","25","24","24","25","24","24",
                   "24","0","25","25","25","25","25","24","24","24","22","24","25","23","24"
